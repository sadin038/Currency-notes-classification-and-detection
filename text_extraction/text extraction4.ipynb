# %%
import cv2
import pytesseract as pt
import matplotlib.pyplot as plt

# %%
img = cv2.cvtColor(cv2.imread('ttt.png'),cv2.COLOR_BGR2RGB)
print(pt.image_to_string(img,lang='ben'))
plt.imshow(img,cmap='gray')
# Out:
# 1: |. টার ওরে ডিও 7
# এ ! দশ টাকা মিটি,
#
# দি জা পর্িরে এ
#
# শুুাপ
#
# ॥
# ফ2054308 ক, ৯০
